# %%
# import libraries
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
# import data
df = pd.read_csv('waterData.csv')
# is this working/doing anttrhinf?

df.fillna(0)

# capture years as strings
df.head()
# re-shape DF for Seaborn
# (choose) plot
# iterate and make meaningful
# color
# Out:
#                  Unnamed: 0   2015 2015.1 2015.2   2014 2014.1 2014.2   2013  \
# 0                   Country  Rural  Urban  Total  Rural  Urban  Total  Rural
# 1                     China     96     96     96     94     96     95     92
# 2        Dominican Republic     86     97     94     85     97     94     85
# 3                    Mexico     94    100     98     92     99     98     91
# 4  United States of America     97    100     99     97    100     99     97
#
#   2013.1 2013.2  ...   2003.2   2002 2002.1 2002.2   2001 2001.1 2001.2  \
# 0  Urban  Total  ...    Total  Rural  Urban  Total  Rural  Urban  Total
# 1     96     94  ...       81     68     98     80     66     98     78
# 2     97     94  ...       92     82     97     92     82     97     91
# 3     99     97  ...       91     77     95     91     75     95     90
# 4    100     99  ...      NaN    NaN    100    NaN    NaN    100    NaN
#
#     2000 2000.1 2000.2
# 0  Rural  Urban  Total
# ...

# %%
# Capture the years which are currently column heads as a list
# years = list(df.iloc[:,1:])

years = list(df.iloc[:, 1:])
print(years)

# capture rural/urban/total which are currently first row
# area = list(df.iloc[0])
# remove 'country' from list of areas
# area.pop(0)
# print(area)

# check to make sure arrays will be the same length for DF
print(len(years))
# print(len(area))
# Out:
# ['2015', '2015.1', '2015.2', '2014', '2014.1', '2014.2', '2013', '2013.1', '2013.2', '2012', '2012.1', '2012.2', '2011', '2011.1', '2011.2', '2010', '2010.1', '2010.2', '2009', '2009.1', '2009.2', '2008', '2008.1', '2008.2', '2007', '2007.1', '2007.2', '2006', '2006.1', '2006.2', '2005', '2005.1', '2005.2', '2004', '2004.1', '2004.2', '2003', '2003.1', '2003.2', '2002', '2002.1', '2002.2', '2001', '2001.1', '2001.2', '2000', '2000.1', '2000.2']
# 48

# %%
# get each remaining row as a list
as_lists = []
# create a list for the values of each row 
for index, row in df.iterrows() :
    # append the list of each rows values to the list of lists
    as_lists.append(list(row))
    print(len(row))
    
print(as_lists)
# Out:
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# 49
# ...

# %%
# as_lists has a list of each columns values I want. 
# with a couple changes still to make 
# wassup with ths nans lists at the end?
# 'Country' needs to be poped from the rural/urban/total
# what else before I make some column names in an object and turn that into a DF?!?!
