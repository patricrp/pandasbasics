# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import rcParams

# %% [markdown]
# # Data Wrangling

# %%
df = pd.read_csv('Food_Preference.csv')

# %%
df = df.dropna()

# %%
df.head()
# Out:
#                      Timestamp Participant_ID  Gender Nationality  Age  \
# 0  2019/05/07 2:59:13 PM GMT+8         FPS001    Male      Indian   24
# 1  2019/05/07 2:59:45 PM GMT+8         FPS002  Female      Indian   22
# 2  2019/05/07 3:00:05 PM GMT+8         FPS003    Male      Indian   31
# 3  2019/05/07 3:00:11 PM GMT+8         FPS004  Female      Indian   25
# 4  2019/05/07 3:02:50 PM GMT+8         FPS005    Male      Indian   27
#
#                Food              Juice Dessert
# 0  Traditional food        Fresh Juice   Maybe
# 1      Western Food  Carbonated drinks     Yes
# 2      Western Food        Fresh Juice   Maybe
# 3  Traditional food        Fresh Juice   Maybe
# 4  Traditional food        Fresh Juice   Maybe

# %%
df['Date'] = pd.to_datetime(df['Timestamp'])

# %%
df['Day'] = df.Date.dt.day 
df.head()
# Out:
#                      Timestamp Participant_ID  Gender Nationality  Age  \
# 0  2019/05/07 2:59:13 PM GMT+8         FPS001    Male      Indian   24
# 1  2019/05/07 2:59:45 PM GMT+8         FPS002  Female      Indian   22
# 2  2019/05/07 3:00:05 PM GMT+8         FPS003    Male      Indian   31
# 3  2019/05/07 3:00:11 PM GMT+8         FPS004  Female      Indian   25
# 4  2019/05/07 3:02:50 PM GMT+8         FPS005    Male      Indian   27
#
#                Food              Juice Dessert                      Date  Day
# 0  Traditional food        Fresh Juice   Maybe 2019-05-07 14:59:13-08:00    7
# 1      Western Food  Carbonated drinks     Yes 2019-05-07 14:59:45-08:00    7
# 2      Western Food        Fresh Juice   Maybe 2019-05-07 15:00:05-08:00    7
# 3  Traditional food        Fresh Juice   Maybe 2019-05-07 15:00:11-08:00    7
# 4  Traditional food        Fresh Juice   Maybe 2019-05-07 15:02:50-08:00    7

# %% [markdown]
# # Plotting with matplotlib

# %%
plt.style.use("bmh") #Style

# %% [markdown]
# # Type of food

# %%
x_values = df['Food'].unique()
y_values = df['Food'].value_counts().tolist()

plt.bar(x_values, y_values)
plt.show()
plt.close('all')

# %% [markdown]
# # Dessert

# %%
x_values = df.Dessert.unique()
y_values = df.Dessert.value_counts().tolist()

plt.figure()    #Figura. Puede incluirse el tamaño con figsize
plt.bar(x_values, y_values)          #El gráfico
plt.title('Pedidos de postres')      #El título
ax = plt.subplot()                   #Axis
ax.set_xticks(x_values)             #Eje x
ax.set_xticklabels(x_values)        #Etiquetas del eje x
ax.set_xlabel('Petición de postre')  #Nombre del eje x
ax.set_ylabel('Volumen de peticiones')  #Nombre del eje y
plt.show()
plt.close('all')
# Out:
# <ipython-input-7-9ba15b846071>:7: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = plt.subplot()                   #Axis

# %% [markdown]
# # Food, beverage and dessert

# %%
plt.figure()    #Figura. Puede incluirse el tamaño con figsize
x_values1 = df.Food.unique()
y_values1 = df.Food.value_counts().tolist()
ax = plt.subplot(1, 3, 1)                   #Axis
plt.bar(x_values1, y_values1)          #El gráfico
plt.title('Pedidos de comida')      #El título
ax.set_xticks(x_values1)             #Eje x
ax.set_xticklabels(x_values1, rotation=60)        #Etiquetas del eje x
ax.set_xlabel('Tipos de comida')  #Nombre del eje x
ax.set_ylabel('Volumen de peticiones')  #Nombre del eje y

x_values2 = df.Juice.unique()
y_values2 = df.Juice.value_counts().tolist()
ax = plt.subplot(1, 3, 2)                   #Axis
plt.bar(x_values2, y_values2)          #El gráfico
plt.title('Pedidos de bebidas')      #El título
ax.set_xticks(x_values2)             #Eje x
ax.set_xticklabels(x_values2, rotation=60)        #Etiquetas del eje x
ax.set_xlabel('Tipos de bebida')  #Nombre del eje x
ax.set_ylabel('Volumen de peticiones')  #Nombre del eje y

x_values3 = df.Dessert.unique()
y_values3 = df.Dessert.value_counts().tolist()
ax = plt.subplot(1, 3, 3)                   #Axis
plt.bar(x_values3, y_values3)          #El gráfico
plt.title('Pedidos de postres')      #El título
ax.set_xticks(x_values3)             #Eje x
ax.set_xticklabels(x_values3, rotation=60)        #Etiquetas del eje x
ax.set_xlabel('Petición de postre')  #Nombre del eje x
ax.set_ylabel('Volumen de peticiones')  #Nombre del eje y

plt.subplots_adjust(wspace=2, bottom=0.3)
plt.show()
plt.close('all')

# %% [markdown]
# # Orders by day

# %%
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = 'Tahoma'
plt.rcParams['xtick.color']='#A8A8A9'
plt.rcParams['ytick.color']='#A8A8A9'

# %%
plt.figure(figsize=(8, 6))
x_values5 = ['Martes', 'Miércoles', 'Jueves', 'Viernes']
y_values5 = df['Day'].value_counts().tolist()
ax = plt.subplot(1, 2, 1)
plt.plot(x_values5, y_values5, color='#a12424', linestyle='--', marker='o')
plt.title('Volumen de pedidos por día')
ax.set_xlabel('Días de la semana') #Nombre del eje x
ax.set_ylabel('Número de pedidos') #Nombre del eje y
for i, txt in enumerate(y_values5):
    ax.annotate(txt, (x_values5[i], y_values5[i]))

    
y_values6 = df[(df['Food'] == 'Traditional food')]['Day'].value_counts().tolist()
y_values7 = df[(df['Food'] == 'Western Food')]['Day'].value_counts().tolist()
ax = plt.subplot(1, 2, 2)
plt.plot(x_values5, y_values6, color='#ee7b06', linestyle='--', marker='*')
plt.plot(y_values7, color='#ffdb00', linestyle='--', marker='s')
plt.title('Volumen de pedidos por día')
plt.legend(['Traditional food', 'Western food'], loc=1)
ax.set_xlabel('Días de la semana') #Nombre del eje x
ax.set_ylabel('Número de pedidos') #Nombre del eje y
for i, txt in enumerate(y_values6):
    ax.annotate(txt, (x_values5[i], y_values6[i]))

for i, txt in enumerate(y_values7):
    ax.annotate(txt, (x_values5[i], y_values7[i]))
    
plt.subplots_adjust(wspace=0.85, bottom=0.3)
plt.show()
plt.close('all')

# %%
plt.figure()
plt.subplot(1, 2, 1)
plt.plot(x_values5, y_values5)
plt.subplot(1, 2, 2)
plt.plot(x_values5, y_values6)
plt.plot(y_values7)

# %% [markdown]
# # Age

# %%
df["Decade"] = pd.cut(df.Age, 10, labels=range(0,100,10))
df.groupby("Decade").agg({"Age": "count"}).plot.bar()

# %%
plt.hist(df.Age, bins=20)
# Out:
# (array([ 4.,  6.,  6., 38., 56., 48., 34., 20., 37.,  6.,  8.,  5.,  5.,
#          2.,  3.,  2.,  1.,  0.,  1.,  2.]),
#  array([ 8. , 11.6, 15.2, 18.8, 22.4, 26. , 29.6, 33.2, 36.8, 40.4, 44. ,
#         47.6, 51.2, 54.8, 58.4, 62. , 65.6, 69.2, 72.8, 76.4, 80. ]),
#  <a list of 20 Patch objects>)

# %% [markdown]
# # Orders by age

# %%
df['Decade'] = pd.cut(df.Age, bins = 9)
df.Decade.value_counts()
# Out:
# (24.0, 32.0]     96
# (16.0, 24.0]     75
# (32.0, 40.0]     66
# (40.0, 48.0]     14
# (48.0, 56.0]     12
# (7.928, 16.0]    12
# (56.0, 64.0]      4
# (72.0, 80.0]      3
# (64.0, 72.0]      2
# Name: Decade, dtype: int64

# %%
df2 = df.groupby(['Decade']).agg({'Age': 'count'})
df2
# Out:
#                Age
# Decade
# (7.928, 16.0]   12
# (16.0, 24.0]    75
# (24.0, 32.0]    96
# (32.0, 40.0]    66
# (40.0, 48.0]    14
# (48.0, 56.0]    12
# (56.0, 64.0]     4
# (64.0, 72.0]     2
# (72.0, 80.0]     3

# %%
segmentos = ['0 - 16', '16 - 24', '24 - 32', '32 - 40', '40 - 48', '48 - 56', '56 - 64', '64 - 72', '72 - 80']

# %%
y_values = df2['Age'].tolist()

# %%
n = 1  # This is our first dataset (out of 2)
t = 2 # Number of datasets
d = 9 # Number of sets of bars
w = 1 # Width of each bar
x_values1 = [t*element + w*n for element in range(d)]
x_values1

plt.figure(figsize=(8, 6))
plt.bar(x_values1, y_values)
plt.title('Pedidos por segmento de edad')
ax = plt.subplot()
ax.set_xticks(x_values1)
ax.set_xticklabels(segmentos)
ax.set_xlabel('Segmentos de edad')
ax.set_ylabel('Volumen de pedidos')
plt.legend(['Volumen', 'xxx'], loc=4)
plt.show()
plt.close('all')
# Out:
# <ipython-input-28-741a2995a7f5>:11: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = plt.subplot()

# %%
df3 = df.groupby(['Decade', 'Food']).agg({'Age':'count'})
df3
# Out:
#                                 Age
# Decade        Food
# (7.928, 16.0] Traditional food    4
#               Western Food        8
# (16.0, 24.0]  Traditional food   55
#               Western Food       20
# (24.0, 32.0]  Traditional food   79
#               Western Food       17
# (32.0, 40.0]  Traditional food   61
#               Western Food        5
# (40.0, 48.0]  Traditional food   14
# (48.0, 56.0]  Traditional food   12
# (56.0, 64.0]  Traditional food    4
# (64.0, 72.0]  Traditional food    2
# (72.0, 80.0]  Traditional food    3

# %%
traditional = df3[df3.index.get_level_values('Food').isin(['Traditional food'])].values.tolist()
traditional_food = [i for l in traditional for i in l]
western = df3[df3.index.get_level_values('Food').isin(['Western Food'])].values.tolist()
western_food = [i for l in western for i in l]

#Append 4 '0' because the lenght of the list is not the same
western_food.append(0)
western_food.append(0)
western_food.append(0)
western_food.append(0)
western_food.append(0)
western_food
# Out:
# [8, 20, 17, 5, 0, 0, 0, 0, 0]

# %%
#Plotting together
plt.figure(figsize=(8, 6))
n = 1  # This is our first dataset (out of 2)
t = 2 # Number of datasets
d = 9 # Number of sets of bars
w = 1 # Width of each bar
x_values1 = [t*element + w*n for element in range(d)]

plt.bar(x_values1, y_values, color='#26547c', tick_label=y_values)



n = 2  # This is our first dataset (out of 2)
t = 2 # Number of datasets
d = 9 # Number of sets of bars
w = 1 # Width of each bar
x_values2 = [t*element + w*n for element in range(d)]

plt.bar(x_values2, traditional_food, color='#ffd166')
plt.bar(x_values2, western_food, bottom=traditional_food, color='#ef7e32')

plt.title('Pedidos por segmento de edad')
ax = plt.subplot()
ax.set_xticks(x_values1)
ax.set_xticklabels(segmentos)
ax.set_xlabel('Segmentos de edad')
ax.set_ylabel('Volumen de pedidos')

plt.show()

plt.close('all')
# Out:
# <ipython-input-31-fd0817152097>:23: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = plt.subplot()
